# %% [markdown]
# Deep Learning
# =============
#
# Assignment 3
# ------------
#
# Previously in `2_fullyconnected.ipynb`, you trained a logistic regression and a neural network model.
#
# The goal of this assignment is to explore regularization techniques.

# %%
# These are all the modules we'll be using later. Make sure you can import them
# before proceeding further.
from __future__ import print_function
import numpy as np
import tensorflow as tf
from six.moves import cPickle as pickle

# %% [markdown]
# First reload the data we generated in `1_notmnist.ipynb`.

# %%
pickle_file = '../Assignment1/notMNIST.pickle'

with open(pickle_file, 'rb') as f:
  save = pickle.load(f)
  train_dataset = save['train_dataset']
  train_labels = save['train_labels']
  valid_dataset = save['valid_dataset']
  valid_labels = save['valid_labels']
  test_dataset = save['test_dataset']
  test_labels = save['test_labels']
  del save  # hint to help gc free up memory
  print('Training set', train_dataset.shape, train_labels.shape)
  print('Validation set', valid_dataset.shape, valid_labels.shape)
  print('Test set', test_dataset.shape, test_labels.shape)
# Out:
# Training set (200000, 28, 28) (200000,)
# Validation set (10000, 28, 28) (10000,)
# Test set (10000, 28, 28) (10000,)

# %% [markdown]
# Reformat into a shape that's more adapted to the models we're going to train:
# - data as a flat matrix,
# - labels as float 1-hot encodings.

# %%
image_size = 28
num_labels = 10

def reformat(dataset, labels):
  dataset = dataset.reshape((-1, image_size * image_size)).astype(np.float32)
  # Map 1 to [0.0, 1.0, 0.0 ...], 2 to [0.0, 0.0, 1.0 ...]
  labels = (np.arange(num_labels) == labels[:,None]).astype(np.float32)
  return dataset, labels
train_dataset, train_labels = reformat(train_dataset, train_labels)
valid_dataset, valid_labels = reformat(valid_dataset, valid_labels)
test_dataset, test_labels = reformat(test_dataset, test_labels)
print('Training set', train_dataset.shape, train_labels.shape)
print('Validation set', valid_dataset.shape, valid_labels.shape)
print('Test set', test_dataset.shape, test_labels.shape)
# Out:
# Training set (200000, 784) (200000, 10)
# Validation set (10000, 784) (10000, 10)
# Test set (10000, 784) (10000, 10)

# %%
def accuracy(predictions, labels):
  return (100.0 * np.sum(np.argmax(predictions, 1) == np.argmax(labels, 1))
          / predictions.shape[0])

# %% [markdown]
# ---
# Problem 1
# ---------
#
# Introduce and tune L2 regularization for both logistic and neural network models. Remember that L2 amounts to adding a penalty on the norm of the weights to the loss. In TensorFlow, you can compute the L2 loss for a tensor `t` using `nn.l2_loss(t)`. The right amount of regularization should improve your validation / test accuracy.
#
# ---

# %%
# Logistic Model with Reg
batch_size = 128
REG_CONST = 5e-4

graph = tf.Graph()
with graph.as_default():

    # Input data. For the training data, we use a placeholder that will be fed
    # at run time with a training minibatch.
    tf_train_dataset = tf.placeholder(tf.float32,
                                    shape=(batch_size, image_size * image_size))
    tf_train_labels = tf.placeholder(tf.float32, shape=(batch_size, num_labels))
    tf_valid_dataset = tf.constant(valid_dataset)
    tf_test_dataset = tf.constant(test_dataset)

    # Variables.
    weights = tf.Variable(
        tf.truncated_normal([image_size * image_size, num_labels]))
    biases = tf.Variable(tf.zeros([num_labels]))

    # Training computation.
    logits = tf.matmul(tf_train_dataset, weights) + biases
    loss = tf.reduce_mean(
        tf.nn.softmax_cross_entropy_with_logits(labels=tf_train_labels, logits=logits))

    # Regularizers
    regularizers = tf.nn.l2_loss(weights) + tf.nn.l2_loss(biases)
    loss += REG_CONST * regularizers
    
    # Optimizer.
    optimizer = tf.train.GradientDescentOptimizer(0.5).minimize(loss)

    # Predictions for the training, validation, and test data.
    train_prediction = tf.nn.softmax(logits)
    valid_prediction = tf.nn.softmax(
    tf.matmul(tf_valid_dataset, weights) + biases)
    test_prediction = tf.nn.softmax(tf.matmul(tf_test_dataset, weights) + biases)

# %%
# Run Logistic Model with Reg
num_steps = 3001

with tf.Session(graph=graph) as session:
    tf.global_variables_initializer().run()
    print("Initialized")
    for step in range(num_steps):
        # Pick an offset within the training data, which has been randomized.
        # Note: we could use better randomization across epochs.
        offset = (step * batch_size) % (train_labels.shape[0] - batch_size)
        # Generate a minibatch.
        batch_data = train_dataset[offset:(offset + batch_size), :]
        batch_labels = train_labels[offset:(offset + batch_size), :]
        # Prepare a dictionary telling the session where to feed the minibatch.
        # The key of the dictionary is the placeholder node of the graph to be fed,
        # and the value is the numpy array to feed to it.
        feed_dict = {tf_train_dataset : batch_data, tf_train_labels : batch_labels}
        _, l, predictions = session.run(
            [optimizer, loss, train_prediction], feed_dict=feed_dict)
        if (step % 500 == 0):
            print("Minibatch loss at step %d: %f" % (step, l))
            print("Minibatch accuracy: %.1f%%" % accuracy(predictions, batch_labels))
            print("Validation accuracy: %.1f%%" % accuracy(
                valid_prediction.eval(), valid_labels))
    print("Test accuracy: %.1f%%" % accuracy(test_prediction.eval(), test_labels))
# Out:
# Initialized
# Minibatch loss at step 0: 20.161095
# Minibatch accuracy: 5.5%
# Validation accuracy: 7.6%
# Minibatch loss at step 500: 2.372555
# Minibatch accuracy: 77.3%
# Validation accuracy: 75.9%
# Minibatch loss at step 1000: 1.910457
# Minibatch accuracy: 79.7%
# Validation accuracy: 77.7%
# Minibatch loss at step 1500: 1.362667
# Minibatch accuracy: 83.6%
# Validation accuracy: 78.5%
# Minibatch loss at step 2000: 1.116636
# Minibatch accuracy: 82.8%
# Validation accuracy: 80.2%
# Minibatch loss at step 2500: 1.389755
# Minibatch accuracy: 78.9%
# Validation accuracy: 81.0%
# Minibatch loss at step 3000: 0.922139
# Minibatch accuracy: 78.9%
# Validation accuracy: 81.0%
# Test accuracy: 87.0%

# %%
# NN w/ 1 Hidden Layer + Reg
REG_CONST = 5e-4
batch_size = 128
num_hidden_nodes = 1024

graph = tf.Graph()
with graph.as_default():

    # Input data. For the training data, we use a placeholder that will be fed
    # at run time with a training minibatch.
    tf_train_dataset = tf.placeholder(tf.float32,
                                    shape=(batch_size, image_size * image_size))
    tf_train_labels = tf.placeholder(tf.float32, shape=(batch_size, num_labels))
    tf_valid_dataset = tf.constant(valid_dataset)
    tf_test_dataset = tf.constant(test_dataset)

    # Variables.
    weights_1 = tf.Variable(
        tf.truncated_normal([image_size * image_size, num_hidden_nodes]))
    weights_2 = tf.Variable(
        tf.truncated_normal([num_hidden_nodes, num_labels]))
    biases_1 = tf.Variable(tf.zeros([num_hidden_nodes]))
    biases_2 = tf.Variable(tf.zeros([num_labels]))

    # Training computation.
    layer_1 = tf.nn.relu(tf.matmul(tf_train_dataset, weights_1) + biases_1)
    logits = tf.matmul(layer_1, weights_2) + biases_2
    loss = tf.reduce_mean(
        tf.nn.softmax_cross_entropy_with_logits(labels=tf_train_labels, logits=logits))
  
    # Regularizers
    regularizers = (tf.nn.l2_loss(weights_1) + tf.nn.l2_loss(biases_1) +
                    tf.nn.l2_loss(weights_2) + tf.nn.l2_loss(biases_2))
    loss += REG_CONST * regularizers
    
    # Optimizer.
    optimizer = tf.train.GradientDescentOptimizer(0.5).minimize(loss)

    # Predictions for the training, validation, and test data.
    train_prediction = tf.nn.softmax(logits)
    layer_1_valid = tf.nn.relu(tf.matmul(tf_valid_dataset, weights_1) + biases_1)
    valid_prediction = tf.nn.softmax(
        tf.matmul(layer_1_valid, weights_2) + biases_2)
    layer_1_test = tf.nn.relu(tf.matmul(tf_test_dataset, weights_1) + biases_1)
    test_prediction = tf.nn.softmax(tf.matmul(layer_1_test, weights_2) + biases_2)

# %%
# Run NN + Reg

num_steps = 3001

with tf.Session(graph=graph) as session:
    tf.global_variables_initializer().run()
    print("Initialized")
    for step in range(num_steps):
        # Note: we could use better randomization across epochs.
        offset = (step * batch_size) % (train_labels.shape[0] - batch_size)
        batch_data = train_dataset[offset:(offset + batch_size), :]
        batch_labels = train_labels[offset:(offset + batch_size), :]
        feed_dict = {tf_train_dataset : batch_data, tf_train_labels : batch_labels}
        _, l, predictions = session.run(
            [optimizer, loss, train_prediction], feed_dict=feed_dict)
        if (step % 500 == 0):
            print("Minibatch loss at step %d: %f" % (step, l))
            print("Minibatch accuracy: %.1f%%" % accuracy(predictions, batch_labels))
            print("Validation accuracy: %.1f%%" % accuracy(
                valid_prediction.eval(), valid_labels))
    print("Test accuracy: %.1f%%" % accuracy(test_prediction.eval(), test_labels))
# Out:
# Initialized
# Minibatch loss at step 0: 527.441528
# Minibatch accuracy: 7.8%
# Validation accuracy: 30.6%
# Minibatch loss at step 500: 126.577026
# Minibatch accuracy: 82.8%
# Validation accuracy: 80.3%
# Minibatch loss at step 1000: 107.303490
# Minibatch accuracy: 79.7%
# Validation accuracy: 78.9%
# Minibatch loss at step 1500: 74.049538
# Minibatch accuracy: 85.9%
# Validation accuracy: 82.5%
# Minibatch loss at step 2000: 57.620724
# Minibatch accuracy: 86.7%
# Validation accuracy: 83.2%
# Minibatch loss at step 2500: 45.823143
# Minibatch accuracy: 79.7%
# Validation accuracy: 83.6%

# %% [markdown]
# ---
# Problem 2
# ---------
# Let's demonstrate an extreme case of overfitting. Restrict your training data to just a few batches. What happens?
#
# ---

# %%
# Run NN + Reg w/ restriced training data

num_steps = 3001

with tf.Session(graph=graph) as session:
    tf.global_variables_initializer().run()
    print("Initialized")
    for step in range(num_steps):
        # Only train on first three batch_sizes
        offset = (step * batch_size) % 3*batch_size
        batch_data = train_dataset[offset:(offset + batch_size), :]
        batch_labels = train_labels[offset:(offset + batch_size), :]
        feed_dict = {tf_train_dataset : batch_data, tf_train_labels : batch_labels}
        _, l, predictions = session.run(
            [optimizer, loss, train_prediction], feed_dict=feed_dict)
        if (step % 500 == 0):
            print(offset, offset+batch_size)
            print("Minibatch loss at step %d: %f" % (step, l))
            print("Minibatch accuracy: %.1f%%" % accuracy(predictions, batch_labels))
            print("Validation accuracy: %.1f%%" % accuracy(
                valid_prediction.eval(), valid_labels))
    print("Test accuracy: %.1f%%" % accuracy(test_prediction.eval(), test_labels))

# %% [markdown]
# ---
# Problem 3
# ---------
# Introduce Dropout on the hidden layer of the neural network. Remember: Dropout should only be introduced during training, not evaluation, otherwise your evaluation results would be stochastic as well. TensorFlow provides `nn.dropout()` for that, but you have to make sure it's only inserted during training.
#
# What happens to our extreme overfitting case?
#
# ---

# %%
# NN w/ 1 Hidden Layer + Reg + Dropout
REG_CONST = 5e-4
batch_size = 128
num_hidden_nodes = 1024

graph = tf.Graph()
with graph.as_default():

    # Input data. For the training data, we use a placeholder that will be fed
    # at run time with a training minibatch.
    tf_train_dataset = tf.placeholder(tf.float32,
                                    shape=(batch_size, image_size * image_size))
    tf_train_labels = tf.placeholder(tf.float32, shape=(batch_size, num_labels))
    tf_valid_dataset = tf.constant(valid_dataset)
    tf_test_dataset = tf.constant(test_dataset)

    # Variables.
    weights_1 = tf.Variable(
        tf.truncated_normal([image_size * image_size, num_hidden_nodes]))
    weights_2 = tf.Variable(
        tf.truncated_normal([num_hidden_nodes, num_labels]))
    biases_1 = tf.Variable(tf.zeros([num_hidden_nodes]))
    biases_2 = tf.Variable(tf.zeros([num_labels]))

    keep_prob = tf.placeholder(tf.float32)

    # Training computation.
    hidden_1 = tf.nn.dropout(tf.nn.relu(tf.matmul(tf_train_dataset, weights_1) + biases_1), keep_prob)
    logits = tf.matmul(hidden_1, weights_2) + biases_2
    loss = tf.reduce_mean(
        tf.nn.softmax_cross_entropy_with_logits(labels=tf_train_labels, logits=logits))
  
    # Regularizers
    regularizers = (tf.nn.l2_loss(weights_1) + tf.nn.l2_loss(biases_1) +
                    tf.nn.l2_loss(weights_2) + tf.nn.l2_loss(biases_2))
    loss += REG_CONST * regularizers
    
    # Optimizer.
    optimizer = tf.train.GradientDescentOptimizer(0.5).minimize(loss)

    # Predictions for the training, validation, and test data.
    train_prediction = tf.nn.softmax(logits)
    layer_1_valid = tf.nn.relu(tf.matmul(tf_valid_dataset, weights_1) + biases_1)
    valid_prediction = tf.nn.softmax(
        tf.matmul(layer_1_valid, weights_2) + biases_2)
    layer_1_test = tf.nn.relu(tf.matmul(tf_test_dataset, weights_1) + biases_1)
    test_prediction = tf.nn.softmax(tf.matmul(layer_1_test, weights_2) + biases_2)

# %%
# Run NN + Reg + Dropout

num_steps = 3001

with tf.Session(graph=graph) as session:
    tf.global_variables_initializer().run()
    print("Initialized")
    for step in range(num_steps):
        # Note: we could use better randomization across epochs.
        offset = (step * batch_size) % (train_labels.shape[0] - batch_size)
        batch_data = train_dataset[offset:(offset + batch_size), :]
        batch_labels = train_labels[offset:(offset + batch_size), :]
        feed_dict = {tf_train_dataset : batch_data, tf_train_labels : batch_labels, keep_prob : .75}
        _, l, predictions = session.run(
            [optimizer, loss, train_prediction], feed_dict=feed_dict)
        if (step % 500 == 0):
            print("Minibatch loss at step %d: %f" % (step, l))
            print("Minibatch accuracy: %.1f%%" % accuracy(train_prediction.eval(feed_dict=
                                                                                {tf_train_dataset : batch_data, 
                                                                                 tf_train_labels : batch_labels, 
                                                                                 keep_prob:1.0}), 
                                                          batch_labels))
            print("Validation accuracy: %.1f%%" % accuracy(
                valid_prediction.eval(feed_dict={keep_prob:1.0}), valid_labels))
    print("Test accuracy: %.1f%%" % accuracy(test_prediction.eval(feed_dict={keep_prob:1.0}), test_labels))

# %% [markdown]
# ---
# Problem 4
# ---------
#
# Try to get the best performance you can using a multi-layer model! The best reported test accuracy using a deep network is [97.1%](http://yaroslavvb.blogspot.com/2011/09/notmnist-dataset.html?showComment=1391023266211#c8758720086795711595).
#
# One avenue you can explore is to add multiple layers.
#
# Another one is to use learning rate decay:
#
#     global_step = tf.Variable(0)  # count the number of steps taken.
#     learning_rate = tf.train.exponential_decay(0.5, global_step, ...)
#     optimizer = tf.train.GradientDescentOptimizer(learning_rate).minimize(loss, global_step=global_step)
#
#  ---

# %%
batch_size = 128
hidden_layer1_size = 1024
hidden_layer2_size = 305
hidden_lastlayer_size = 75

use_multilayers = True

regularization_meta=0.03


graph = tf.Graph()
with graph.as_default():

    # Input data. For the training data, we use a placeholder that will be fed
    # at run time with a training minibatch.
    tf_train_dataset = tf.placeholder(tf.float32,
                                    shape=(batch_size, image_size * image_size))
    tf_train_labels = tf.placeholder(tf.float32, shape=(batch_size, num_labels))
    tf_valid_dataset = tf.constant(valid_dataset)
    tf_test_dataset = tf.constant(test_dataset)

    # Variables.
    keep_prob = tf.placeholder(tf.float32)

    weights_layer1 = tf.Variable(
    tf.truncated_normal([image_size * image_size, hidden_layer1_size], stddev=0.0517))
    biases_layer1 = tf.Variable(tf.zeros([hidden_layer1_size]))

    if use_multilayers:
        weights_layer2 = tf.Variable(
            tf.truncated_normal([hidden_layer1_size, hidden_layer1_size], stddev=0.0441))
        biases_layer2 = tf.Variable(tf.zeros([hidden_layer1_size]))

        weights_layer3 = tf.Variable(
            tf.truncated_normal([hidden_layer1_size, hidden_layer2_size], stddev=0.0441))
        biases_layer3 = tf.Variable(tf.zeros([hidden_layer2_size]))

        weights_layer4 = tf.Variable(
            tf.truncated_normal([hidden_layer2_size, hidden_lastlayer_size], stddev=0.0809))
        biases_layer4 = tf.Variable(tf.zeros([hidden_lastlayer_size]))


    weights = tf.Variable(
        tf.truncated_normal([hidden_lastlayer_size if use_multilayers else hidden_layer1_size, num_labels], 
                            stddev=0.1632))
    biases = tf.Variable(tf.zeros([num_labels]))
  
    
    # get the NN models
    def getNN4Layer(dSet, use_dropout):
        input_to_layer1 = tf.matmul(dSet, weights_layer1) + biases_layer1
        hidden_layer1_output = tf.nn.relu(input_to_layer1)

        logits_hidden1 = None
        if use_dropout:
            dropout_hidden1 = tf.nn.dropout(hidden_layer1_output, keep_prob)
            logits_hidden1 = tf.matmul(dropout_hidden1, weights_layer2) + biases_layer2
        else:
            logits_hidden1 = tf.matmul(hidden_layer1_output, weights_layer2) + biases_layer2

        hidden_layer2_output = tf.nn.relu(logits_hidden1)

        logits_hidden2 = None
        if use_dropout:
            dropout_hidden2 = tf.nn.dropout(hidden_layer2_output, keep_prob)
            logits_hidden2 = tf.matmul(dropout_hidden2, weights_layer3) + biases_layer3
        else:
            logits_hidden2 = tf.matmul(hidden_layer2_output, weights_layer3) + biases_layer3


        hidden_layer3_output = tf.nn.relu(logits_hidden2)
        logits_hidden3 = None
        if use_dropout:
            dropout_hidden3 = tf.nn.dropout(hidden_layer3_output, keep_prob)
            logits_hidden3 = tf.matmul(dropout_hidden3, weights_layer4) + biases_layer4
        else:
            logits_hidden3 = tf.matmul(hidden_layer3_output, weights_layer4) + biases_layer4


        hidden_layer4_output = tf.nn.relu(logits_hidden3)
        logits = None
        if use_dropout:
            dropout_hidden4 = tf.nn.dropout(hidden_layer4_output, keep_prob)
            logits = tf.matmul(dropout_hidden4, weights) + biases
        else:
            logits = tf.matmul(hidden_layer4_output, weights) + biases

        return logits

    # get the NN models
    def getNN1Layer(dSet, use_dropout, w1, b1, w, b):
        input_to_layer1 = tf.matmul(dSet, w1) + b1
        hidden_layer1_output = tf.nn.relu(input_to_layer1)

        logits = None
        if use_dropout:
             dropout_hidden1 = tf.nn.dropout(hidden_layer1_output, keep_prob)
             logits = tf.matmul(dropout_hidden1, w) + b
        else:
            logits = tf.matmul(hidden_layer1_output, w) + b

        return logits

  
  
    # Training computation.
    logits = getNN4Layer(tf_train_dataset, True)  
    logits_valid = getNN4Layer(tf_valid_dataset, False)
    logits_test = getNN4Layer(tf_test_dataset, False)


    loss = tf.reduce_mean(
        tf.nn.softmax_cross_entropy_with_logits(logits, tf_train_labels))
    #loss_l2 = loss + (regularization_meta * (tf.nn.l2_loss(weights)))

    global_step = tf.Variable(0)  # count the number of steps taken.
    learning_rate = tf.train.exponential_decay(0.3, global_step, 3500, 0.86, staircase=True)


    # Optimizer.
    optimizer = tf.train.GradientDescentOptimizer(learning_rate).minimize(loss, global_step=global_step)

    # Predictions for the training, validation, and test data.
    train_prediction = tf.nn.softmax(logits)
    valid_prediction = tf.nn.softmax(logits_valid)
    test_prediction = tf.nn.softmax(logits_test)

# %%
num_steps = 95001

with tf.Session(graph=graph) as session:
    tf.global_variables_initializer().run()
    print("Initialized")
    for step in range(num_steps):
        # Note: we could use better randomization across epochs.
        offset = (step * batch_size) % (train_labels.shape[0] - batch_size)
        batch_data = train_dataset[offset:(offset + batch_size), :]
        batch_labels = train_labels[offset:(offset + batch_size), :]
        feed_dict = {tf_train_dataset : batch_data, tf_train_labels : batch_labels, keep_prob : .75}
        _, l, predictions = session.run(
            [optimizer, loss, train_prediction], feed_dict=feed_dict)
        if (step % 500 == 0):
            print("Minibatch loss at step %d: %f" % (step, l))
            print("Minibatch accuracy: %.1f%%" % accuracy(train_prediction.eval(feed_dict=
                                                                                {tf_train_dataset : batch_data, 
                                                                                 tf_train_labels : batch_labels, 
                                                                                 keep_prob:1.0}), 
                                                          batch_labels))
            print("Validation accuracy: %.1f%%" % accuracy(
                valid_prediction.eval(feed_dict={keep_prob:1.0}), valid_labels))
    print("Test accuracy: %.1f%%" % accuracy(test_prediction.eval(feed_dict={keep_prob:1.0}), test_labels))
# Out:
# Initialized
# Minibatch loss at step 0: 2.426123
# Minibatch accuracy: 40.6%
# Validation accuracy: 28.0%
# Minibatch loss at step 500: 0.486983
# Minibatch accuracy: 89.1%
# Validation accuracy: 85.3%
# Minibatch loss at step 1000: 0.556825
# Minibatch accuracy: 89.1%
# Validation accuracy: 86.5%
# Minibatch loss at step 1500: 0.388233
# Minibatch accuracy: 90.6%
# Validation accuracy: 87.4%
# Minibatch loss at step 2000: 0.445661
# Minibatch accuracy: 90.6%
# Validation accuracy: 87.9%
# Minibatch loss at step 2500: 0.501541
# Minibatch accuracy: 88.3%
# Validation accuracy: 88.6%
# Minibatch loss at step 3000: 0.555456
# Minibatch accuracy: 89.8%
# Validation accuracy: 88.1%
# Minibatch loss at step 3500: 0.387585
# Minibatch accuracy: 89.8%
# Validation accuracy: 88.8%
# Minibatch loss at step 4000: 0.399982
# Minibatch accuracy: 92.2%
# Validation accuracy: 89.0%
# Minibatch loss at step 4500: 0.386213
# Minibatch accuracy: 93.8%
# Validation accuracy: 89.3%
# Minibatch loss at step 5000: 0.357329
# Minibatch accuracy: 92.2%
# Validation accuracy: 89.8%
# Minibatch loss at step 5500: 0.462270
# Minibatch accuracy: 92.2%
# Validation accuracy: 89.6%
# Minibatch loss at step 6000: 0.342977
# Minibatch accuracy: 90.6%
# Validation accuracy: 89.8%
# Minibatch loss at step 6500: 0.288945
# Minibatch accuracy: 93.0%
# Validation accuracy: 89.9%
# Minibatch loss at step 7000: 0.224889
# Minibatch accuracy: 95.3%
# Validation accuracy: 90.1%
# Minibatch loss at step 7500: 0.374968
# Minibatch accuracy: 92.2%
# Validation accuracy: 90.2%
# Minibatch loss at step 8000: 0.205763
# Minibatch accuracy: 96.1%
# Validation accuracy: 90.3%
# Minibatch loss at step 8500: 0.319651
# Minibatch accuracy: 94.5%
# Validation accuracy: 90.3%
# Minibatch loss at step 9000: 0.332070
# Minibatch accuracy: 93.8%
# Validation accuracy: 90.3%
# Minibatch loss at step 9500: 0.318054
# Minibatch accuracy: 93.0%
# Validation accuracy: 90.7%
# Minibatch loss at step 10000: 0.350917
# Minibatch accuracy: 91.4%
# Validation accuracy: 90.7%
# Minibatch loss at step 10500: 0.247788
# Minibatch accuracy: 93.8%
# Validation accuracy: 90.8%
# Minibatch loss at step 11000: 0.240539
# Minibatch accuracy: 96.1%
# Validation accuracy: 90.8%
# Minibatch loss at step 11500: 0.284331
# Minibatch accuracy: 92.2%
# Validation accuracy: 90.8%
# Minibatch loss at step 12000: 0.314444
# Minibatch accuracy: 90.6%
# Validation accuracy: 90.7%
# Minibatch loss at step 12500: 0.256517
# Minibatch accuracy: 97.7%
# Validation accuracy: 91.0%
# Minibatch loss at step 13000: 0.163371
# Minibatch accuracy: 98.4%
# Validation accuracy: 91.0%
# Minibatch loss at step 13500: 0.261822
# Minibatch accuracy: 93.8%
# Validation accuracy: 90.8%
# Minibatch loss at step 14000: 0.254766
# Minibatch accuracy: 93.8%
# Validation accuracy: 91.0%
# Minibatch loss at step 14500: 0.194772
# Minibatch accuracy: 96.1%
# Validation accuracy: 91.0%
# Minibatch loss at step 15000: 0.145648
# Minibatch accuracy: 98.4%
# Validation accuracy: 91.3%
# Minibatch loss at step 15500: 0.062509
# Minibatch accuracy: 99.2%
# Validation accuracy: 91.2%
# Minibatch loss at step 16000: 0.268976
# Minibatch accuracy: 93.8%
# Validation accuracy: 91.3%
# Minibatch loss at step 16500: 0.229949
# Minibatch accuracy: 93.0%
# Validation accuracy: 91.2%
# Minibatch loss at step 17000: 0.247016
# Minibatch accuracy: 96.1%
# Validation accuracy: 91.3%
# Minibatch loss at step 17500: 0.230434
# Minibatch accuracy: 96.9%
# Validation accuracy: 91.2%
# Minibatch loss at step 18000: 0.349407
# Minibatch accuracy: 92.2%
# Validation accuracy: 91.5%
# Minibatch loss at step 18500: 0.176289
# Minibatch accuracy: 97.7%
# Validation accuracy: 91.4%
# Minibatch loss at step 19000: 0.198491
# Minibatch accuracy: 97.7%
# Validation accuracy: 91.4%
# Minibatch loss at step 19500: 0.178595
# Minibatch accuracy: 97.7%
# Validation accuracy: 91.3%
# Minibatch loss at step 20000: 0.281886
# Minibatch accuracy: 97.7%
# Validation accuracy: 91.5%
# Minibatch loss at step 20500: 0.182401
# Minibatch accuracy: 96.9%
# Validation accuracy: 91.6%
# Minibatch loss at step 21000: 0.191052
# Minibatch accuracy: 96.9%
# Validation accuracy: 91.5%
# Minibatch loss at step 21500: 0.235332
# Minibatch accuracy: 94.5%
# Validation accuracy: 91.5%
# Minibatch loss at step 22000: 0.331335
# Minibatch accuracy: 89.8%
# Validation accuracy: 91.4%
# Minibatch loss at step 22500: 0.118036
# Minibatch accuracy: 97.7%
# Validation accuracy: 91.3%
# Minibatch loss at step 23000: 0.132100
# Minibatch accuracy: 97.7%
# Validation accuracy: 91.6%
# Minibatch loss at step 23500: 0.253089
# Minibatch accuracy: 99.2%
# Validation accuracy: 91.6%
# Minibatch loss at step 24000: 0.202404
# Minibatch accuracy: 95.3%
# Validation accuracy: 91.6%
# Minibatch loss at step 24500: 0.098708
# Minibatch accuracy: 99.2%
# Validation accuracy: 91.5%
# Minibatch loss at step 25000: 0.221147
# Minibatch accuracy: 95.3%
# Validation accuracy: 91.8%
# Minibatch loss at step 25500: 0.176520
# Minibatch accuracy: 95.3%
# Validation accuracy: 91.6%
# Minibatch loss at step 26000: 0.207047
# Minibatch accuracy: 94.5%
# Validation accuracy: 91.8%
# Minibatch loss at step 26500: 0.151008
# Minibatch accuracy: 96.9%
# Validation accuracy: 91.7%
# Minibatch loss at step 27000: 0.256666
# Minibatch accuracy: 94.5%
# Validation accuracy: 91.7%
# Minibatch loss at step 27500: 0.156369
# Minibatch accuracy: 98.4%
# Validation accuracy: 91.7%
# Minibatch loss at step 28000: 0.135135
# Minibatch accuracy: 99.2%
# Validation accuracy: 91.7%
# Minibatch loss at step 28500: 0.164401
# Minibatch accuracy: 98.4%
# Validation accuracy: 91.7%
# Minibatch loss at step 29000: 0.309278
# Minibatch accuracy: 94.5%
# Validation accuracy: 91.9%
# Minibatch loss at step 29500: 0.151212
# Minibatch accuracy: 99.2%
# Validation accuracy: 91.8%
# Minibatch loss at step 30000: 0.118614
# Minibatch accuracy: 97.7%
# Validation accuracy: 91.9%
# Minibatch loss at step 30500: 0.262107
# Minibatch accuracy: 97.7%
# Validation accuracy: 91.7%
# Minibatch loss at step 31000: 0.157674
# Minibatch accuracy: 96.9%
# Validation accuracy: 91.9%
# Minibatch loss at step 31500: 0.085890
# Minibatch accuracy: 98.4%
# Validation accuracy: 91.8%
# Minibatch loss at step 32000: 0.127003
# Minibatch accuracy: 98.4%
# Validation accuracy: 91.8%
# Minibatch loss at step 32500: 0.199110
# Minibatch accuracy: 97.7%
# Validation accuracy: 92.1%
# Minibatch loss at step 33000: 0.080233
# Minibatch accuracy: 100.0%
# Validation accuracy: 92.2%
# Minibatch loss at step 33500: 0.137311
# Minibatch accuracy: 99.2%
# Validation accuracy: 92.0%
# Minibatch loss at step 34000: 0.126883
# Minibatch accuracy: 98.4%
# Validation accuracy: 92.0%
# Minibatch loss at step 34500: 0.094088
# Minibatch accuracy: 98.4%
# Validation accuracy: 92.0%
# Minibatch loss at step 35000: 0.121422
# Minibatch accuracy: 98.4%
# Validation accuracy: 92.0%
# Minibatch loss at step 35500: 0.119440
# Minibatch accuracy: 97.7%
# Validation accuracy: 92.0%
# Minibatch loss at step 36000: 0.072938
# Minibatch accuracy: 99.2%
# Validation accuracy: 92.0%
# Minibatch loss at step 36500: 0.105082
# Minibatch accuracy: 97.7%
# Validation accuracy: 92.0%
# Minibatch loss at step 37000: 0.326915
# Minibatch accuracy: 93.8%
# Validation accuracy: 91.9%
# Minibatch loss at step 37500: 0.162692
# Minibatch accuracy: 99.2%
# Validation accuracy: 92.0%
# Minibatch loss at step 38000: 0.296594
# Minibatch accuracy: 96.9%
# Validation accuracy: 92.1%
# Minibatch loss at step 38500: 0.056859
# Minibatch accuracy: 100.0%
# Validation accuracy: 92.0%
# Minibatch loss at step 39000: 0.144198
# Minibatch accuracy: 97.7%
# Validation accuracy: 92.0%
# Minibatch loss at step 39500: 0.087462
# Minibatch accuracy: 99.2%
# Validation accuracy: 92.1%
# Minibatch loss at step 40000: 0.111504
# Minibatch accuracy: 99.2%
# Validation accuracy: 92.0%
# Minibatch loss at step 40500: 0.131376
# Minibatch accuracy: 96.9%
# Validation accuracy: 92.0%
# Minibatch loss at step 41000: 0.114331
# Minibatch accuracy: 97.7%
# Validation accuracy: 92.0%
# Minibatch loss at step 41500: 0.156600
# Minibatch accuracy: 97.7%
# Validation accuracy: 92.0%
# Minibatch loss at step 42000: 0.184361
# Minibatch accuracy: 96.1%
# Validation accuracy: 92.2%
# Minibatch loss at step 42500: 0.037160
# Minibatch accuracy: 99.2%
# Validation accuracy: 92.1%
# Minibatch loss at step 43000: 0.077185
# Minibatch accuracy: 100.0%
# Validation accuracy: 92.2%
# Minibatch loss at step 43500: 0.159794
# Minibatch accuracy: 96.9%
# Validation accuracy: 92.2%
# Minibatch loss at step 44000: 0.165234
# Minibatch accuracy: 98.4%
# Validation accuracy: 92.1%
# Minibatch loss at step 44500: 0.113664
# Minibatch accuracy: 98.4%
# Validation accuracy: 92.1%
# Minibatch loss at step 45000: 0.137960
# Minibatch accuracy: 98.4%
# Validation accuracy: 92.1%
# Minibatch loss at step 45500: 0.110147
# Minibatch accuracy: 97.7%
# Validation accuracy: 92.2%
# Minibatch loss at step 46000: 0.130185
# Minibatch accuracy: 98.4%
# Validation accuracy: 92.2%
# Minibatch loss at step 46500: 0.145205
# Minibatch accuracy: 99.2%
# Validation accuracy: 92.2%
# Minibatch loss at step 47000: 0.160342
# Minibatch accuracy: 96.1%
# Validation accuracy: 92.2%
# Minibatch loss at step 47500: 0.121881
# Minibatch accuracy: 98.4%
# Validation accuracy: 92.0%
# Minibatch loss at step 48000: 0.203004
# Minibatch accuracy: 96.9%
# Validation accuracy: 92.2%
# Minibatch loss at step 48500: 0.079420
# Minibatch accuracy: 98.4%
# Validation accuracy: 92.2%
# Minibatch loss at step 49000: 0.068349
# Minibatch accuracy: 99.2%
# Validation accuracy: 92.1%
# Minibatch loss at step 49500: 0.124062
# Minibatch accuracy: 96.1%
# Validation accuracy: 92.1%
# Minibatch loss at step 50000: 0.107874
# Minibatch accuracy: 97.7%
# Validation accuracy: 92.2%
# Minibatch loss at step 50500: 0.300086
# Minibatch accuracy: 95.3%
# Validation accuracy: 92.0%
# Minibatch loss at step 51000: 0.111151
# Minibatch accuracy: 96.9%
# Validation accuracy: 92.2%
# Minibatch loss at step 51500: 0.160089
# Minibatch accuracy: 96.9%
# Validation accuracy: 92.1%
# Minibatch loss at step 52000: 0.032677
# Minibatch accuracy: 100.0%
# Validation accuracy: 92.2%
# Minibatch loss at step 52500: 0.212071
# Minibatch accuracy: 96.1%
# Validation accuracy: 92.1%
# Minibatch loss at step 53000: 0.144574
# Minibatch accuracy: 96.1%
# Validation accuracy: 92.1%
# Minibatch loss at step 53500: 0.169325
# Minibatch accuracy: 96.9%
# Validation accuracy: 92.1%
# Minibatch loss at step 54000: 0.235561
# Minibatch accuracy: 93.8%
# Validation accuracy: 92.1%
# Minibatch loss at step 54500: 0.101243
# Minibatch accuracy: 100.0%
# Validation accuracy: 92.2%
# Minibatch loss at step 55000: 0.108233
# Minibatch accuracy: 98.4%
# Validation accuracy: 92.2%
# Minibatch loss at step 55500: 0.117229
# Minibatch accuracy: 98.4%
# Validation accuracy: 92.2%
# Minibatch loss at step 56000: 0.135882
# Minibatch accuracy: 97.7%
# Validation accuracy: 92.2%
# Minibatch loss at step 56500: 0.052353
# Minibatch accuracy: 98.4%
# Validation accuracy: 92.2%
# Minibatch loss at step 57000: 0.109328
# Minibatch accuracy: 97.7%
# Validation accuracy: 92.4%
# Minibatch loss at step 57500: 0.154810
# Minibatch accuracy: 98.4%
# Validation accuracy: 92.2%
# Minibatch loss at step 58000: 0.131812
# Minibatch accuracy: 100.0%
# Validation accuracy: 92.2%
# Minibatch loss at step 58500: 0.108612
# Minibatch accuracy: 99.2%
# Validation accuracy: 92.2%
# Minibatch loss at step 59000: 0.119629
# Minibatch accuracy: 97.7%
# Validation accuracy: 92.3%
# Minibatch loss at step 59500: 0.114936
# Minibatch accuracy: 98.4%
# Validation accuracy: 92.2%
# Minibatch loss at step 60000: 0.121475
# Minibatch accuracy: 99.2%
# Validation accuracy: 92.3%
# Minibatch loss at step 60500: 0.156088
# Minibatch accuracy: 97.7%
# Validation accuracy: 92.3%
# Minibatch loss at step 61000: 0.061525
# Minibatch accuracy: 100.0%
# Validation accuracy: 92.2%
# Minibatch loss at step 61500: 0.113126
# Minibatch accuracy: 97.7%
# Validation accuracy: 92.3%
# Minibatch loss at step 62000: 0.082493
# Minibatch accuracy: 100.0%
# Validation accuracy: 92.3%
# Minibatch loss at step 62500: 0.179394
# Minibatch accuracy: 97.7%
# Validation accuracy: 92.3%
# Minibatch loss at step 63000: 0.106203
# Minibatch accuracy: 99.2%
# Validation accuracy: 92.2%
# Minibatch loss at step 63500: 0.141958
# Minibatch accuracy: 98.4%
# Validation accuracy: 92.2%
# Minibatch loss at step 64000: 0.116904
# Minibatch accuracy: 100.0%
# Validation accuracy: 92.3%
# Minibatch loss at step 64500: 0.093436
# Minibatch accuracy: 98.4%
# Validation accuracy: 92.2%
# Minibatch loss at step 65000: 0.137035
# Minibatch accuracy: 97.7%
# Validation accuracy: 92.4%
# Minibatch loss at step 65500: 0.127342
# Minibatch accuracy: 96.9%
# Validation accuracy: 92.3%
# Minibatch loss at step 66000: 0.185694
# Minibatch accuracy: 96.9%
# Validation accuracy: 92.2%
# Minibatch loss at step 66500: 0.206130
# Minibatch accuracy: 97.7%
# Validation accuracy: 92.3%
# Minibatch loss at step 67000: 0.138955
# Minibatch accuracy: 97.7%
# Validation accuracy: 92.3%
# Minibatch loss at step 67500: 0.134144
# Minibatch accuracy: 98.4%
# Validation accuracy: 92.3%
# Minibatch loss at step 68000: 0.204159
# Minibatch accuracy: 97.7%
# Validation accuracy: 92.3%
# Minibatch loss at step 68500: 0.160868
# Minibatch accuracy: 97.7%
# Validation accuracy: 92.3%
# Minibatch loss at step 69000: 0.148030
# Minibatch accuracy: 98.4%
# Validation accuracy: 92.4%
# Minibatch loss at step 69500: 0.103982
# Minibatch accuracy: 100.0%
# Validation accuracy: 92.2%
# Minibatch loss at step 70000: 0.138039
# Minibatch accuracy: 97.7%
# Validation accuracy: 92.3%
# Minibatch loss at step 70500: 0.133402
# Minibatch accuracy: 98.4%
# Validation accuracy: 92.3%
# Minibatch loss at step 71000: 0.046151
# Minibatch accuracy: 99.2%
# Validation accuracy: 92.2%
# Minibatch loss at step 71500: 0.046329
# Minibatch accuracy: 98.4%
# Validation accuracy: 92.3%
# Minibatch loss at step 72000: 0.063193
# Minibatch accuracy: 99.2%
# Validation accuracy: 92.3%
# Minibatch loss at step 72500: 0.037049
# Minibatch accuracy: 99.2%
# Validation accuracy: 92.3%
# Minibatch loss at step 73000: 0.160747
# Minibatch accuracy: 96.9%
# Validation accuracy: 92.3%
# Minibatch loss at step 73500: 0.117949
# Minibatch accuracy: 100.0%
# Validation accuracy: 92.3%
# Minibatch loss at step 74000: 0.126313
# Minibatch accuracy: 99.2%
# Validation accuracy: 92.4%
# Minibatch loss at step 74500: 0.129902
# Minibatch accuracy: 97.7%
# Validation accuracy: 92.3%
# Minibatch loss at step 75000: 0.066510
# Minibatch accuracy: 100.0%
# Validation accuracy: 92.3%
# Minibatch loss at step 75500: 0.071680
# Minibatch accuracy: 97.7%
# Validation accuracy: 92.3%
# Minibatch loss at step 76000: 0.071397
# Minibatch accuracy: 100.0%
# Validation accuracy: 92.3%
# Minibatch loss at step 76500: 0.143859
# Minibatch accuracy: 96.1%
# Validation accuracy: 92.2%
# Minibatch loss at step 77000: 0.057746
# Minibatch accuracy: 99.2%
# Validation accuracy: 92.2%
# Minibatch loss at step 77500: 0.156999
# Minibatch accuracy: 99.2%
# Validation accuracy: 92.3%
# Minibatch loss at step 78000: 0.144978
# Minibatch accuracy: 96.9%
# Validation accuracy: 92.3%
# Minibatch loss at step 78500: 0.100524
# Minibatch accuracy: 100.0%
# Validation accuracy: 92.4%
# Minibatch loss at step 79000: 0.109327
# Minibatch accuracy: 100.0%
# Validation accuracy: 92.4%
# Minibatch loss at step 79500: 0.128740
# Minibatch accuracy: 97.7%
# Validation accuracy: 92.2%
# Minibatch loss at step 80000: 0.130502
# Minibatch accuracy: 98.4%
# Validation accuracy: 92.3%
# Minibatch loss at step 80500: 0.100313
# Minibatch accuracy: 96.9%
# Validation accuracy: 92.2%
# Minibatch loss at step 81000: 0.114912
# Minibatch accuracy: 97.7%
# Validation accuracy: 92.4%
# Minibatch loss at step 81500: 0.094980
# Minibatch accuracy: 98.4%
# Validation accuracy: 92.3%
# Minibatch loss at step 82000: 0.077645
# Minibatch accuracy: 97.7%
# Validation accuracy: 92.4%
# Minibatch loss at step 82500: 0.253322
# Minibatch accuracy: 99.2%
# Validation accuracy: 92.3%
# Minibatch loss at step 83000: 0.077180
# Minibatch accuracy: 98.4%
# Validation accuracy: 92.4%
# Minibatch loss at step 83500: 0.073471
# Minibatch accuracy: 98.4%
# Validation accuracy: 92.3%
# Minibatch loss at step 84000: 0.047378
# Minibatch accuracy: 99.2%
# Validation accuracy: 92.4%
# Minibatch loss at step 84500: 0.080495
# Minibatch accuracy: 100.0%
# Validation accuracy: 92.4%
# Minibatch loss at step 85000: 0.152929
# Minibatch accuracy: 98.4%
# Validation accuracy: 92.3%
# Minibatch loss at step 85500: 0.071850
# Minibatch accuracy: 99.2%
# Validation accuracy: 92.4%
# Minibatch loss at step 86000: 0.115580
# Minibatch accuracy: 97.7%
# Validation accuracy: 92.5%
# Minibatch loss at step 86500: 0.090041
# Minibatch accuracy: 99.2%
# Validation accuracy: 92.4%
# Minibatch loss at step 87000: 0.052289
# Minibatch accuracy: 99.2%
# Validation accuracy: 92.3%
# Minibatch loss at step 87500: 0.081453
# Minibatch accuracy: 99.2%
# Validation accuracy: 92.4%
# Minibatch loss at step 88000: 0.113558
# Minibatch accuracy: 98.4%
# Validation accuracy: 92.4%
# Minibatch loss at step 88500: 0.116770
# Minibatch accuracy: 96.9%
# Validation accuracy: 92.5%
# Minibatch loss at step 89000: 0.120969
# Minibatch accuracy: 99.2%
# Validation accuracy: 92.4%
# Minibatch loss at step 89500: 0.138419
# Minibatch accuracy: 100.0%
# Validation accuracy: 92.4%
# Minibatch loss at step 90000: 0.117826
# Minibatch accuracy: 97.7%
# Validation accuracy: 92.5%
# Minibatch loss at step 90500: 0.126665
# Minibatch accuracy: 100.0%
# Validation accuracy: 92.4%
# Minibatch loss at step 91000: 0.075677
# Minibatch accuracy: 100.0%
# Validation accuracy: 92.5%
# Minibatch loss at step 91500: 0.032525
# Minibatch accuracy: 99.2%
# Validation accuracy: 92.4%
# Minibatch loss at step 92000: 0.056945
# Minibatch accuracy: 100.0%
# Validation accuracy: 92.4%
# Minibatch loss at step 92500: 0.045668
# Minibatch accuracy: 100.0%
# Validation accuracy: 92.5%
# Minibatch loss at step 93000: 0.189152
# Minibatch accuracy: 94.5%
# Validation accuracy: 92.5%
# Minibatch loss at step 93500: 0.106857
# Minibatch accuracy: 99.2%
# Validation accuracy: 92.5%
# Minibatch loss at step 94000: 0.095695
# Minibatch accuracy: 97.7%
# Validation accuracy: 92.5%
# Minibatch loss at step 94500: 0.082803
# Minibatch accuracy: 98.4%
# Validation accuracy: 92.4%
# Minibatch loss at step 95000: 0.125209
# Minibatch accuracy: 99.2%
# Validation accuracy: 92.3%
# Test accuracy: 96.6%
